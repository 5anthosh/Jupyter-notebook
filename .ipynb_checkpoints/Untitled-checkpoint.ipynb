# %%
import matplotlib.pyplot as plt
plt.plot([(1,2),(23,4),(4,1)])
plt.show()

# %%
# !conda env list
# Out:
# # conda environments:
# #
# yourenvname              C:\Users\USER\AppData\Local\conda\conda\envs\yourenvname
# app                      C:\ProgramData\Anaconda3\envs\app
# app1                     C:\ProgramData\Anaconda3\envs\app1
# py3.5                    C:\ProgramData\Anaconda3\envs\py3.5
# pyexe                    C:\ProgramData\Anaconda3\envs\pyexe
# pyexe1                   C:\ProgramData\Anaconda3\envs\pyexe1
# python2               *  C:\ProgramData\Anaconda3\envs\python2
# root                     C:\ProgramData\Anaconda3
